# %% [markdown]
# # **KELOMPOK MARKOV 1**
#
# **Anggota Kelompok :**
#
# Rindy Eka Putri (1911071002)
#
# Rara Yetrisia Putri (1911012024)
#
# Fadhilah Hanin(1911072016)
#
# RIJALUL HADI (190170159)
#
# Nadila Khairanisa (1911071010)
#
# Rivani Widya Astuti (1911071009

# %% [markdown]
# ## **Aplikasi Chatbot untuk Sistem Informasi Akademik Universitas Malikusshaleh**

# %% [markdown]
# **Referensi data : Ide bersama**

# %%
#install gtts

# !pip install gtts
# Out:
# Collecting gtts
#   Downloading gTTS-2.2.4-py3-none-any.whl (26 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gtts) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from gtts) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from gtts) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->gtts) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->gtts) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->gtts) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->gtts) (2021.10.8)
# Installing collected packages: gtts
# Successfully installed gtts-2.2.4

# %%
# Import library
import random
import nltk
import string
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import pandas as pd
import warnings
import re
warnings.filterwarnings('ignore')

from gtts import gTTS
import IPython.display as ipd
import time
from io import BytesIO

# %% [markdown]
# Membuka dataset yang digunakan sebagai basic pengetahuan chatbot

# %%
df = pd.read_csv('pertanyaanmahasiswa.txt', header=None, delimiter='\t')
df
# Out:
#                                                     0  \
# 0                       Apa Beda Non Aktif dan Cuti ?
# 1           Dari Semester berapa Cuti Boleh diambil ?
# 2                         Apa Konsekuensi Non aktif ?
# 3                              Apa Konsekuensi Cuti ?
# 4    Berapa Kali boleh Mengambil Cuti Selama Kuliah ?
# 5                        Kapan Masa Pengurusan Cuti ?
# 6                   Bagaiman Proses Pengurusan Cuti ?
# 7                     Bagaimana Cara Pembayaran SPP ?
# 8             Apa Boleh Bayar SPP tanpa No. Invoice ?
# 9                   Dari mana No. Invoice diperoleh ?
# 10                  Untuk yang Bidik Misi Bagaimana ?
# 11  Setelah Bayar SPP apa perlu registrasi lagi un...
# 12  Apa perlu Foto Copy Slip Pembayaran SPP di Kum...
# 13              apa ada perpanjangan pembayaran SPP ?
# 14  Apa harus Konsultasi dulu ke Pembimbing Akadem...
# 15   Apa Boleh Pengisian KRS di Lakukan di Luar UTU ?
# 16  Apa Konsekuensi apabila Mahasiswa isi KRS tanp...
# 17  Apa yang dilakukan apabila ada Mata kuliah yan...
# 18        Apa wajib bawa borang  waktu konsul ke PA ?
# 19  Jika perlu Borang Nilai Sementara dimana bisa ...
#
#                                                     1
# 0   Non Aktif  (Meninggalkan Kegiatan Akademik pad...
# 1   Cuti baru bisa diambil oleh mahasiswa mulai se...
# 2   Semester tersebut dihitung sebagai semester be...
# 3   Semester tersebut tidak dihitung sebagai semes...
# 4   Selama Kuliah, Cuti boleh diambil sebanyak 2 (...
# 5   Masa Pengurusan Cuti dapat dilihat pada Kelend...
# 6   Download Surat Permohonan di Sini , Lalu lengk...
# 7   Pembayaran SPP Boleh diLakukan ViaTeller Bank ...
# 8                                         Tidak Boleh
# 9            Dari Portal Sia Masing-Masing Mahasiswa
# 10  Bagi Mahasiswa yang terdaftar Bidik Misi  akan...
# 11  Tidak Perlu, setelah pembayaran otomatis sudah...
# 12  Perlu, Selambat-lambat nya dikumpulkan 2 mingg...
# 13  Perpanjangan Pembayaran SPP kewenangan Biro Re...
# 14                                         Iya harus.
# 15  Boleh dimana saja, asalkan sudah Konsultasi de...
# 16  Pembimbing Akademik tidak menyetujui Mata Kuli...
# 17  Segera mengisi Form Pengaduan Pengisian KRS di...
# 18                        Tergantung PA masing-masing
# 19                        Silahkan di Download disini

# %% [markdown]
# Mengekstrak feature menggunakan TF-IDF

# %%
#Extract Feature

from sklearn.feature_extraction.text import TfidfVectorizer

vec = TfidfVectorizer(lowercase=True)
X = vec.fit_transform(df[0])
question = X.toarray()

# %% [markdown]
# Pembuatan Chatbot

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
print('Bot : Selamat datang di Sistem Informasi Layanan Administrasi Universitas Malikusshaleh. Apa yang bisa kami bantu? Silahkan ajukan pertanyaan anda di bawah ini!') 
tts = gTTS('Selamat datang di Sistem Informasi Layanan Administrasi Universitas Malikusshaleh. Apa yang bisa kami bantu? Silahkan ajukan pertanyaan anda di bawah ini!', lang='id')
tts.save('pembukaan.wav')
            
exit_list = ['exit', 'sampai jumpa', 'close', 'tutup', 'bye', 'quit', 'break', 'stop']

while True:
  text = input('Mahasiswa : ').lower()
  if text in exit_list:
    print('Bot: Terimakasih telah mengunjungi layanan kami, semoga jawaban kami bisa menjawab pertanyaan anda :)')
    tts = gTTS('Terimakasih telah mengunjungi layanan kami, semoga jawaban kami bisa menjawab pertanyaan anda', lang='id')
    tts.save('terimakasih.wav')
    time.sleep(0.08)
    ipd.display(ipd.Audio('terimakasih.wav', autoplay=True))
            
    break
  else:
    text_vec = vec.transform([text])
    text_vec = text_vec.toarray()
    text_vec = text_vec[0].reshape(1, -1) 
    similarity = cosine_similarity(text_vec, question)
    answer_index = np.argmax(similarity[0])
    answer = df[1].iloc[answer_index]
    tts = gTTS(answer, lang='id')
    tts.save('jawaban.wav')
    time.sleep(0.08)
    print('Bot: ', answer)
    ipd.display(ipd.Audio('jawaban.wav', autoplay=True))
# Out:
# Bot : Selamat datang di Sistem Informasi Layanan Administrasi Universitas Malikusshaleh. Apa yang bisa kami bantu? Silahkan ajukan pertanyaan anda di bawah ini!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8a3bb60caff7> in <module>()
#       1 print('Bot : Selamat datang di Sistem Informasi Layanan Administrasi Universitas Malikusshaleh. Apa yang bisa kami bantu? Silahkan ajukan pertanyaan anda di bawah ini!')
# ----> 2 tts = gTTS('Selamat datang di Sistem Informasi Layanan Administrasi Universitas Malikusshaleh. Apa yang bisa kami bantu? Silahkan ajukan pertanyaan anda di bawah ini!', lang='id')
#       3 tts.save('pembukaan.wav')
#       4
#       5 exit_list = ['exit', 'sampai jumpa', 'close', 'tutup', 'bye', 'quit', 'break', 'stop']
#
# NameError: name 'gTTS' is not defined

# %% [markdown]
# Gambaran kedepannya yaitu aplikasi ini akan kami kembangkan pada bagian layanan informasi yang ada di kampus, pada project ini kami contohkan Universitas Malikusshaleh
