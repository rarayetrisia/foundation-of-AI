# %% [markdown]
# #2. Read Data

# %%
import pandas as pd

# %%
df = pd.read_csv('dialogs.txt', header=None, delimiter='\t')
df
# Out:
#                                                       0  \
# 0                                hi, how are you doing?
# 1                         i'm fine. how about yourself?
# 2                   i'm pretty good. thanks for asking.
# 3                     no problem. so how have you been?
# 4                      i've been great. what about you?
# ...                                                 ...
# 3720    that's a good question. maybe it's not old age.
# 3721                              are you right-handed?
# 3722                                  yes. all my life.
# 3723  you're wearing out your right hand. stop using...
# 3724        but i do all my writing with my right hand.
#
#                                                       1
# 0                         i'm fine. how about yourself?
# 1                   i'm pretty good. thanks for asking.
# 2                     no problem. so how have you been?
# 3                      i've been great. what about you?
# 4              i've been good. i'm in school right now.
# ...                                                 ...
# 3720                              are you right-handed?
# 3721                                  yes. all my life.
# 3722  you're wearing out your right hand. stop using...
# 3723        but i do all my writing with my right hand.
# 3724  start typing instead. that way your left hand ...
#
# [3725 rows x 2 columns]

# %% [markdown]
# #3. Extract Feature

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vec = TfidfVectorizer(lowercase=True)
X = vec.fit_transform(df[0])
question = X.toarray()

# %%
len(question[0])
# Out:
# 2315

# %% [markdown]
# #4. Ayo bikin chatbot

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
print('Bot: Hi I am a Bot. To exit, type [bye].') 
exit_list = ['exit', 'see you later', 'bye', 'quit', 'break', 'stop']

while True:
  text = input('Me: ').lower()
  if text in exit_list:
    print('Bot: Chat with you later, stay safe!!')
    break
  else:
    text_vec = vec.transform([text])
    text_vec = text_vec.toarray()

    text_vec = text_vec[0].reshape(1, -1) 
    similarity = cosine_similarity(text_vec, question)
    answer_index = np.argmax(similarity[0])
    answer = df[1].iloc[answer_index]
    print('Bot: ', answer)
# Out:
# Bot: Hi I am a Bot. To exit, type [bye].
# Bot:  i'm fine. how about yourself?
# Bot:  we have to find a cheaper house.
# Bot:  we went to a nice restaurant.
# Bot:  i'm a babysitter.
# Bot:  two students from usc.
# Bot:  yes. all my life.
# Bot:  to show respect to god and others.
# Bot:  i love you, too.
# Bot:  i loved you the first day i saw you.
# Bot:  when he is almost finished with one cigarette, he uses it to light another.
# Bot:  she's one of the prettiest girls at the school.
# Bot:  then you don't date her again.
# Bot:  no. he was nice, but there was no chemistry.
# Bot:  are you going to college?
# Bot:  i had a long day.
# Bot:  i can't afford it.
# Bot:  even if it's only for a short while.
