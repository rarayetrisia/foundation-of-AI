# %% [markdown]
# # **Structured Query Language**
#
# **SQL** adalah singkatan dari **Structured Query Language**. Ini adalah bahasa pilihan di web saat ini untuk menyimpan, memanipulasi dan mengambil data dalam Sistem Manajemen Basis Data Relasional (RDBMS). Bahasa seperti SQL juga dapat digunakan dalam Aliran **Data Relasional Sistem Manajemen (RDSMS)**, atau dalam database **"tidak hanya SQL" (NoSQL)**.
#
# SQL terdiri dari 2 sub-bahasa utama:​
#
# 1. **Data Definition Language (DDL)**: untuk membuat dan memodifikasi struktur database;​
# 2. **Data Manipulation Language (DML)**: untuk melakukan operasi Baca, Sisipkan, Perbarui, dan Hapus pada data;
#
# Dalam SQL memiliki delapan tipe data yang paling sering digunakan:​
#
# 1. **Integer.** Bilangan bulat tanpa bagian pecahan. Misalnya. 1, 156, 2012412​.
#
# 2. **Decimal.** Bilangan dengan bagian pecahan. Misalnya. 3.14, 3.141592654, 961.1241250​.
#
# 3. **Boolean.** Sebuah nilai biner. Ini bisa berupa TRUE atau FALSE.​
#
# 4. **Date.** Digunakan untuk menyimpan data tanggal. Misalnya. 2017-12-31​.
#
# 5. **Time.** Digunakan untuk menyimpan data waktu. Misalnya. 23:59:59​.
#
# 6. **Timestamp.** Tanggal dan waktu bersama. Misalnya. 31-12-2017 23:59:59​.
#
# 7. **Float.** Digunakan untuk menyimpan data bilangan pecahan positif dan negatif presisi tunggal. Misalnya. -3.402823466E+38 sampai 3.402823466E+38​.
#
# 8. **String.** Ini adalah tipe data yang paling umum. Tapi itu hanya bisa huruf abjad,​ atau campuran huruf dan angka dan karakter lainnya. Misalnya. halo, R2D2,​ Tomi, 124.56.128.41.

# %% [markdown]
# # **Koneksi Ke Database**
#
# Kita akan mulai menghubungkan ke database:
#
# Sebelum kita mulai jangan lupa untuk mengupload file database ke google colab.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Type code here


""" 
  Kita dapat menggunakan metode connect() untuk membuat koneksi 
  ke database SQLite 
"""
#Type code here

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
"""
  Setelah koneksi kita dibuat dengan database, kita harus membuat kursor. 
  Kursor adalah alat yang digunakan untuk melintasi dan mengambil catatan 
  dalam database.
  
"""
#Type code here

# %% [markdown]
# Kursor memiliki peran utama karena kita akan menggunakannya setiap kali kita akan menjalankan kueri SQL dari Python.
#
# Metode kursor untuk menjalankan kueri SQL meliputi:
# <ul>
#   <li><b>execute():</b> mengeksekusi satu pernyataan SQL,</li>
#   <li><b>executemany():</b> mengeksekusi perintah SQL berparameter dengan beberapa   urutan parameter,</li>
#   <li><b>executescript():</b> mengeksekusi beberapa pernyataan SQL sekaligus.</li>
# </ul>

# %% [markdown]
# **PENTING:**
# <br>
# <p align="justify">
# Pernyataan SQL yang mengubah database (CREATE, DROP, INSERT, UPDATE, DELETE, dll.) tidak langsung berlaku, kita harus melakukan perubahan setelah setiap pernyataan.Jika database diakses oleh beberapa koneksi yang memodifikasinya, SQLite akan mengunci database sampai perubahan tersebut dilakukan. Jadi, jangan pernah lupa untuk melakukan perubahan Anda setelah setiap pernyataan SQL Anda.
# </p>
#
# Untuk melakukan transaksi, cukup jalankan metode commit():

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Perintah untuk menampilkan list tabel nama yang ada di dalam database



# Eksekusi perintah


# Commit perubahan yang terjadi pada database

# %% [markdown]
# Untuk mengambil baris dengan database SQLite menggunakan Python, kita dapat:
#
# <ul>
# <li>Perlakukan kursor sebagai iterator,</li>
# <li><b>Panggil metode fetchone()</b>, dimana kursor mengambil baris berikutnya dari kumpulan hasil kueri, mengembalikan satu urutan.</li>
# <li><b>Panggil metode fetchall()</b>, dimana kursor mengambil baris berikutnya dari kumpulan hasil kueri. Jumlah baris berikutnya yang akan diambil harus ditentukan sebagai parameter metode. Baris yang diambil dikembalikan dalam daftar Python dengan tupel.</li>
# <li><b>Panggil metode fetchmany()</b>, dimana kursor mengambil semua baris dari kumpulan hasil kueri. Baris yang diambil dikembalikan dalam daftar Python dengan tupel.</li>
# </ul>

# %%
# Menampilkan hasil list tabel nama yang ada di dalam database dalam bentuk dataframe
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)
results_data

# %% [markdown]
# # **DDL - Membuat Tabel Books**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Perintah untuk membuat tabel books





# Eksekusi Perintah


# Commit perubahan yang terjadi pada database

# %% [markdown]
# # **DDL - ALTER Tabel Books (Menambahkan Kolom Baru)**
#
# Perintah ini digunakan untuk mengubah struktur tabel yang telah dibuat. Pekerjaannya mencakup mengganti nama tabel, menambah kolom, mengubah kolom, menghapus kolom, maupun memberikan atribut pada kolom.​
# <br>
# <br>
# Query ALTER :
#
#     ALTER TABLE ​<table_name>
#       Add (new_column_name_1 data_type_1,...,
#     new_column_name_n, data_type_n);

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Perintah untuk membuat kolom baru dengan nama page di tabel books



# Eksekusi perintah


# Commit perubahan yang terjadi pada database

# %% [markdown]
# # **DDL - Membuat Tabel Authors**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Perintah untuk membuat tabel authors




# Eksekusi perintah


# Commit perubahan yang terjadi pada database

# %% [markdown]
# # **DDL - Membuat Tabel Editors**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Perintah untuk membuat tabel editors




# Eksekusi perintah


# Commit perubahan yang terjadi pada database

# %% [markdown]
# # **DDL - Membuat Tabel Translators**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Perintah untuk membuat tabel translators




# Eksekusi perintah


# Commit perubahan yang terjadi pada database

# %%
# Perintah untuk menampilkan list tabel nama yang sudah berhasil kita buat
command = '''
          SELECT
              name
          FROM sqlite_master
          WHERE type IN ("table","view");
          '''
result.execute(command)

# Commit perubahan yang terjadi pada database
connection.commit()

# Menampilkan hasil list tabel nama yang sudah dibuat dan masuk ke database dalam bentuk dataframe
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)
results_data

# %% [markdown]
# # **DDL - DROP Tabel**
#
# Menghapus tabel pada database.
# <br>
# <br>
# Query DROP :
# ```python
#     DROP <table_name>;
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Perintah untuk menghapus tabel translators


# Eksekusi beberapa perintah diatas


# Commit perubahan yang terjadi pada database

# %% [markdown]
# # **DML - INSERT INTO Tabel Books**
# <br>
# <table>
#   <tr>
#     <th>book_id</th>
#     <th>title</th>
#     <th>type</th>
#     <th>price</th>
#     <th>author_id</th>
#     <th>editor_id</th>
#     <th>page</th>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Time to Grow Up!</td>
#     <td>Original</td>
#     <td>2500.00</td>
#     <td>AA11</td>
#     <td>AA21</td>
#     <td>185</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>Your Trip</td>
#     <td>Translated</td>
#     <td>3500.00</td>
#     <td>AA15</td>
#     <td>AA22</td>
#     <td>190</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>Lovely Love</td>
#     <td>Original</td>
#     <td>2500.00</td>
#     <td>AA14</td>
#     <td>AA24</td>
#     <td>265</td>
#   </tr>
#   <tr>
#     <td>4</td>
#     <td>Dream Your Life</td>
#     <td>Translated</td>
#     <td>4000.00</td>
#     <td>AA11</td>
#     <td>AA24</td>
#     <td>365</td>
#   </tr>
#   <tr>
#     <td>5</td>
#     <td>Oranges</td>
#     <td>Translated</td>
#     <td>1500.00</td>
#     <td>AA12</td>
#     <td>AA25</td>
#     <td>255</td>
#   </tr>
#   <tr>
#     <td>6</td>
#     <td>Your Happy Life</td>
#     <td>Translated</td>
#     <td>3500.00</td>
#     <td>AA15</td>
#     <td>AA22</td>
#     <td>418</td>
#   </tr>
#   <tr>
#     <td>7</td>
#     <td>Applied AI</td>
#     <td>Translated</td>
#     <td>2500.00</td>
#     <td>AA13</td>
#     <td>AA23</td>
#     <td>430</td>
#   </tr>
#   <tr>
#     <td>8</td>
#     <td>My Last Book</td>
#     <td>Translated</td>
#     <td>1000.00</td>
#     <td>AA11</td>
#     <td>AA27</td>
#     <td>250</td>
#   </tr>
# </table>

# %%
# Type code here
insert_books = [
    (1, "Time to Grow Up!", "Original", 2500.00, 'AA11', 'AA21', 185),
    (2, "Your Trip", "Translated", 3500.00, 'AA15', 'AA22', 190),
    (3, "Lovely Love", "Original", 2500.00, 'AA14', 'AA24', 265),
    (4, "Dream Your Life", "Translated", 4000.00, 'AA11', 'AA24', 365),
    (5, "Oranges", "Translated", 1500.00, 'AA12', 'AA25', 255),
    (6, "Your Happy Life", "Translated", 3500.00, 'AA15', 'AA22', 418),
    (7, "Applied AI", "Translated", 2500.00, 'AA13', 'AA23', 430),
    (8, "My Last Book", "Translated", 1000.00, 'AA11', 'AA27', 250),
]

# Perintah untuk memasukkan beberapa data ke tabel books
result.executemany("INSERT INTO books VALUES (?, ?, ?, ?, ?, ?, ?)", insert_books)

# Commit perubahan yang terjadi pada database
connection.commit()

# %% [markdown]
# # **DML - INSERT INTO Tabel Authors**
# <br>
# <table>
#   <tr>
#     <th>book_id</th>
#     <th>first_name</th>
#     <th>last_name</th>
#   </tr>
#   <tr>
#     <td>AA11</td>
#     <td>Ellen</td>
#     <td>Writer</td>
#   </tr>
#   <tr>
#     <td>AA12</td>
#     <td>Olga</td>
#     <td>Savelieva</td>
#   </tr>
#   <tr>
#     <td>AA13</td>
#     <td>Jack</td>
#     <td>Smart</td>
#   </tr>
#   <tr>
#     <td>AA14</td>
#     <td>Donald</td>
#     <td>Brain</td>
#   </tr>
#   <tr>
#     <td>AA15</td>
#     <td>Yao</td>
#     <td>Dao</td>
#   </tr>
# </table>

# %%
# Type code here
insert_authors = [
    ('AA11', "Ellen", "Writer"),
    ('AA12', "Olga", "Savelieva"),
    ('AA13', "Jack", "Smart"),
    ('AA14', "Donald", "Brain"),
    ('AA15', "Yao", "Dao"),
]

# Perintah untuk memasukkan beberapa data ke tabel authors
result.executemany("INSERT INTO authors VALUES (?, ?, ?)", insert_authors)

# Commit perubahan yang terjadi pada database
connection.commit()

# %% [markdown]
# # **DML - INSERT INTO Tabel Editors**
# <br>
# <table>
#   <tr>
#     <th>editor_id</th>
#     <th>first_name</th>
#     <th>last_name</th>
#   </tr>
#   <tr>
#     <td>AA21</td>
#     <td>Daniel</td>
#     <td>Brown</td>
#   </tr>
#   <tr>
#     <td>AA22</td>
#     <td>Mark</td>
#     <td>Johnson</td>
#   </tr>
#   <tr>
#     <td>AA23</td>
#     <td>Maria</td>
#     <td>Evans</td>
#   </tr>
#   <tr>
#     <td>AA24</td>
#     <td>Cathrine</td>
#     <td>Roberts</td>
#   </tr>
#   <tr>
#     <td>AA25</td>
#     <td>Sebastian</td>
#     <td>Wright</td>
#   </tr>
#   <tr>
#     <td>AA26</td>
#     <td>Barbara</td>
#     <td>Jones</td>
#   </tr>
#   <tr>
#     <td>AA27</td>
#     <td>Matthew</td>
#     <td>Smith</td>
#   </tr>
# </table>

# %%
# Type code here
insert_editors = [
    ('AA21', "Daniel", "Brown"),
    ('AA22', "Mark", "Johnson"),
    ('AA23', "Maria", "Evans"),
    ('AA24', "Cathrine", "Roberts"),
    ('AA25', "Sebastian", "Wright"),
    ('AA26', "Barbara", "Jones"),
    ('AA27', "Matthew", "Smith"),
]

# Perintah untuk memasukkan beberapa data ke tabel editors
result.executemany("INSERT INTO editors VALUES (?, ?, ?)", insert_editors)

# Commit perubahan yang terjadi pada database
connection.commit()

# %% [markdown]
# # **DML - SELECT**
#
# Mengembalikan kolom tertentu dari tabel (atau lebih).
# <br>
# <br>
# Query SELECT :
# ```python
#     SELECT column_name_1,...,​
#           column_name_n ​
#     FROM <table_name>;
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Type code here
command = ""

result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)
results_data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Type code here
command = ""

result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)
results_data

# %% [markdown]
# # **DML - SELECT With AS (Aliases)**
#
# Menampilkan data tertentu dari sebuah (atau beberapa) tabel dengan ​
# menggantikan nama kolom nya.​
# <br>
# <br>
# Query SELECT with AS:
# ```python
#   SELECT column_name ​
#       AS ’new_column_name’ ​
#   FROM table_name ​
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Type code here
command = ""

result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)
results_data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Type code here
command = ""

result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)
results_data

# %% [markdown]
# # **DML - UPDATE**
#
# Digunakan untuk mengubah nilai atau data pada tabel.
# <br>
# <br>
# **Note:** klausa **WHERE** harap selalu ditulis dengan jelas. Tanpa klausa **WHERE**, maka semua data akan terkena dampak pengubahan.​
# <br>
# <br>
# Query UPDATE :
# ```python
#     UPDATE <table_name> SET  column_name_1='...',
#         column_name_2='...',....,column_name_n='...' ​
#     WHERE <clause>;
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Type code here
command = ""
result.execute(command)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Type code here
command = ""

result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)
results_data

# %% [markdown]
# # **DML - DELETE**
#
# Digunakan untuk menghapus nilai atau data pada tabel.
# <br>
# <br>
# **Note:** klausa **WHERE** harap selalu ditulis dengan jelas. Tanpa klausa **WHERE**, maka semua data akan terkena dampak penghapusan.​
# <br>
# <br>
# Query DELETE :
# ```python
#     DELETE FROM <table_name>​
#         WHERE <clause>;
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Type code here
command = ""
result.execute(command)

# %% [markdown]
# # **DML - SELECT dengan Kriteria**
#
# Menampilkan data tertentu berdasarkan kriteria yang  ditentukan.
# <br>
# Kriteria (disebut juga kondisi), pada klausa WHERE  diatas dapat menggunakan operator logika maupun  operator yang lain.
# <br>
# Query SELECT :
# ```python
#     SELECT column_name_1,...,column_name_n
#         FROM <tabel_name>​
#     WHERE <criteria>​
# ```

# %% [markdown]
# # **DML - SELECT dengan Operator Perbandingan**
#
# Seringkali disebut dengan operator relasional, banyak  digunakan dalam klausa WHERE sebagai parameter  dalam menampilkan data tertentu.​
#
# Dapat juga digunakan untuk keperluan lain, misalnya: percabangan, trigger, prosedur, maupun fungsi.
# <br>
# <br>
#
# <table>
#   <tr>
#     <th>Operator
#     <th>Deskripsi
#   </tr>
#   <tr>
#     <td> =
#     <td> Sama dengan
#   </tr>
#   <tr>
#     <td> !=
#     <td> Tidak sama dengan
#   </tr>
#   <tr>
#     <td> <
#     <td> Kurang dari
#   </tr>
#   <tr>
#     <td> >
#     <td> Lebih dari
#   </tr>
#   <tr>
#     <td> <=
#     <td> Kurang dari sama dengan
#   </tr>
#   <tr>
#     <td> >=
#     <td> Lebih dari sama dengan
#   </tr>
# </table>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Type code here
command = ""

result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)
results_data

# %% [markdown]
# # **DML - SELECT dengan Operator Boolean**
#
# Operator Boolean digunakan untuk menghubungkan antara dua buah  kriteria. Sedangkan operator NOT digunakan untuk  pembalik keadaan kebenaran dari suatu kondisi.
# <br>
# <br>
#
# <table>
#   <tr>
#     <th>Operator
#     <th>Deskripsi
#   </tr>
#   <tr>
#     <td> AND
#     <td> Menampilkan data yang memenuhi kedua kriteria yang diberikan.
#   </tr>
#   <tr>
#     <td> OR
#     <td> Menampilkan data yang memenuhi salah satu, atau kedua kriteria yang diberikan.
#   </tr>
#   <tr>
#     <td> NOT
#     <td> Mengembalikan data yang merupakan kebalikan dari kondisi yang diberikan.
#   </tr>
# </table>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Type code here
command = """ 
          

          """
          
result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)
results_data

# %% [markdown]
# # **DML - Operator Like**
#
# Apabila diperlukan, sebuah informasi dapat ditampilkan  berdasarkan kemiripan kolom tertentu dengan sebuah string.​ Menggunakan operator LIKE.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Type code here
command = ""

result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)
results_data

# %% [markdown]
# # **DML - Operator IN dan NOT IN**
#
# Menampilkan data tertentu dengan kolom yang  mempunyai nilai seperti yang tercantum pada operator  IN dan NOT IN.
#
# ![image.png](data:image/png;base64,...)

# %%
#Type code here
command = """
          

          """
          
result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)
results_data

# %% [markdown]
# # **DML - Operator Between**
#
# Menampilkan data tertentu dengan kolom yang bernilai pada rentang tertentu.
#
# ![image.png](data:image/png;base64,...)

# %%
#Type code here
command = ""

result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)
results_data

# %% [markdown]
# # **DML - Operator ORDER BY**
#
# Menampilkan data tertentu berdasarkan urutan.
#
# ![image.png](data:image/png;base64,...)

# %%
#Type code here
command = ""

result.execute(command)
results = result.fetchall()
cols = [column[0] for column in result.description]
results_data= pd.DataFrame.from_records(results, columns = cols)
results_data

# %% [markdown]
# # **ASSIGNMENT KUIS**
# 1. Apa yang kamu tahu tentang SQL?
#
# 2. Apa yang kamu tahu tentang DML (Data Manipulation Language)?
#
# 3. Sebutkan yang termasuk perintah dalam DML!
#
# 4. Apa yang kamu tahu tentang DDL (Data Definition Language)?
#
# 5. Sebutkan yang termasuk perintah DDL!
#
#
# # **ASSIGNMENT PROGRAM**
#
# Jawablah pertanyaan-pertanyaan berikut dengan SQL.
# 1. Tampilkan data customer yg mempunyai opening amount diatas 7000.
#
# 2. Tampilkan informasi order yg dilakukan melalui agensi dengan code A003.
#
# 3. Tampilkan data customer yg tinggal di New York, Bangalore, Mumbai, dan Torento.
#
# 4. Tampilkan informasi customer yang mempunyai payment amount diatas 7000 dan urutkan berdasarkan opening amountnya dari yg terbesar
#
# 5. Tampilkan data agensi yang tidak bekerja di london dan memiliki comission lebih dari 0.12
