# %%
import cv2
import numpy as np

warna = np.uint8([[[R,G,B ]]])

hsv_warna = cv2.cvtColor(warna,cv2.COLOR_BGR2HSV)
print (hsv_warna)
print (r, g, b)
# Out:
# 340
# 340
# 89255
# [[[  0 255 255]]]
# 34 34 89
